# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import math
import feather
from matplotlib import pyplot as plt
import seaborn as sns
ca_df = pd.read_feather("C:/Attrition/2007-2018.feather", columns=None, use_threads=True)
ca_df.head()
ca_df.shape
ca_df.describe()
# Out:
#         HRECORD    H_SEQ    HHPOS   HUNITS HEFAMINC H_RESPNM   H_YEAR  \
# count   1130205  1130205  1130205  1130205  1130205  1130205  1130205
# unique        1    99461        1        6       19       16       12
# top           1    21021       00        1       -1       01     2015
# freq    1130205       12  1130205   634772   247293   726543    99461
#
#        H_HHTYPE H_NUMPER  HNUMFAM  ... HPROP_VAL THPROP_VAL I_PROPVAL  \
# count   1130205  1130205  1130205  ...   1130205    1130205   1130205
# unique        3       17       14  ...      2106          6         2
# top           1       00       01  ...  00000000          0         0
# freq     861291   268914   744646  ...    731597    1125699   1037953
#
#        HRNUMWIC  HRWICYN   HFDVAL TCARE_VAL CARE_VAL I_CAREVAL HPRES_MORT
# count   1130205  1130205  1130205   1130205  1130205   1130205    1130205
# unique        6        3     2970         2     2282         2          3
# ...
